# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
pd.set_option('display.max_columns', None)

# %%
# %%capture
from tqdm import tqdm_notebook as tqdm
tqdm().pandas()

# %%
df = pd.read_csv('vgsales-12-4-2019.csv')

# %% [markdown]
# ### EDA

# %%
df
# Out:
#         Rank                                          Name  \
# 0          1                                    Wii Sports
# 1          2                             Super Mario Bros.
# 2          3                                Mario Kart Wii
# 3          4                 PlayerUnknown's Battlegrounds
# 4          5                             Wii Sports Resort
# 5          6            Pokemon Red / Green / Blue Version
# 6          7                         New Super Mario Bros.
# 7          8                                        Tetris
# 8          9                     New Super Mario Bros. Wii
# 9         10                                     Minecraft
# 10        11                                     Duck Hunt
# 11        12                                      Wii Play
# 12        13                            Kinect Adventures!
# 13        14                                    Nintendogs
# 14        15                                 Mario Kart DS
# 15        16                 Pokemon Gold / Silver Version
# 16        17                                       Wii Fit
# 17        18                                  Wii Fit Plus
# 18        19                             Super Mario World
# 19        20                            Grand Theft Auto V
# 20        21                            Grand Theft Auto V
# 21        22  Brain Age: Train Your Brain in Minutes a Day
# 22        23                                   Garry's Mod
# 23        24                              Super Mario Land
# 24        25                                  Mario Kart 7
# 25        26               Pokemon Diamond / Pearl Version
# 26        27                 Grand Theft Auto: San Andreas
# 27        28                           Super Mario Bros. 3
# 28        29                                   Pokemon X/Y
# 29        30               Pokemon Ruby / Sapphire Version
# ...      ...                                           ...
# 55762  55763                    Ys VIII: Lacrimosa of Dana
# 55763  55764              Yu Yu Hakusho Tournament Tactics
# 55764  55765               Yunohana SpRING! ~Mellow Times~
# 55765  55766                                 Yuppie Psycho
# 55766  55767                                 Yuppie Psycho
# 55767  55768                                 Yuppie Psycho
# 55768  55769                    Zanki Zero: Last Beginning
# 55769  55770                                        Zarvot
# 55770  55771                                        Zaxxon
# 55771  55772                             Zelda's Adventure
# 55772  55773                                 ZERO GUNNER 2
# 55773  55774                     Zoids Wild: King of Blast
# 55774  55775                                       Zombeer
# 55775  55776                              ZOMBIE GOLD RUSH
# 55776  55777                                     Zombillie
# 55777  55778       Zone of the Enders: The 2nd Runner MARS
# 55778  55779        Zoo Tycoon: Ultimate Animal Collection
# 55779  55780        Zoo Tycoon: Ultimate Animal Collection
# 55780  55781                                   Indivisible
# 55781  55782                                   Indivisible
# 55782  55783                                    Ion Maiden
# 55783  55784                                    Ion Maiden
# 55784  55785                                    Ion Maiden
# 55785  55786                                    Ion Maiden
# 55786  55787                         In the Valley of Gods
# 55787  55788                                   Indivisible
# 55788  55789                                    Lost Ember
# 55789  55790                                    Lost Ember
# 55790  55791                                    Lost Ember
# 55791  55792                                    Falcon Age
#
#                                           basename             Genre  \
# 0                                       wii-sports            Sports
# 1                                 super-mario-bros          Platform
# 2                                   mario-kart-wii            Racing
# 3                     playerunknowns-battlegrounds           Shooter
# 4                                wii-sports-resort            Sports
# 5                                       pokmon-red      Role-Playing
# 6                             new-super-mario-bros          Platform
# 7                                           tetris            Puzzle
# 8                         new-super-mario-bros-wii          Platform
# 9                                        minecraft              Misc
# 10                                       duck-hunt           Shooter
# 11                                        wii-play              Misc
# 12                               kinect-adventures             Party
# 13                                      nintendogs        Simulation
# 14                                   mario-kart-ds            Racing
# 15                                     pokmon-gold      Role-Playing
# 16                                         wii-fit            Sports
# 17                                    wii-fit-plus            Sports
# 18                               super-mario-world          Platform
# 19                              grand-theft-auto-v            Action
# 20                              grand-theft-auto-v            Action
# 21     brain-age-train-your-brain-in-minutes-a-day              Misc
# 22                                      garrys-mod              Misc
# 23                                super-mario-land          Platform
# 24                                    mario-kart-7            Racing
# 25                                  pokmon-diamond      Role-Playing
# 26                    grand-theft-auto-san-andreas            Action
# 27                              super-mario-bros-3          Platform
# 28                                        pokmon-x      Role-Playing
# 29                                     pokmon-ruby      Role-Playing
# ...                                            ...               ...
# 55762                    ys-viii-lacrimosa-of-dana      Role-Playing
# 55763             yu-yu-hakusho-tournament-tactics          Strategy
# 55764                 yunohana-spring-mellow-times      Visual Novel
# 55765                                yuppie-psycho         Adventure
# 55766                                yuppie-psycho         Adventure
# 55767                                yuppie-psycho         Adventure
# 55768                    zanki-zero-last-beginning      Role-Playing
# 55769                                       zarvot            Action
# 55770                                       zaxxon           Shooter
# 55771                             zeldas-adventure  Action-Adventure
# 55772                                zero-gunner-2            Action
# 55773                     zoids-wild-king-of-blast            Action
# 55774                                      zombeer            Action
# 55775                             zombie-gold-rush            Action
# 55776                                    zombillie            Puzzle
# 55777       zone-of-the-enders-the-2nd-runner-mars        Simulation
# 55778        zoo-tycoon-ultimate-animal-collection        Simulation
# 55779        zoo-tycoon-ultimate-animal-collection        Simulation
# 55780                                  indivisible      Role-Playing
# 55781                                  indivisible      Role-Playing
# 55782                                   ion-maiden           Shooter
# 55783                                   ion-maiden           Shooter
# 55784                                   ion-maiden           Shooter
# 55785                                   ion-maiden           Shooter
# 55786                         inthe-valley-of-gods         Adventure
# 55787                                  indivisible      Role-Playing
# 55788                                   lost-amber         Adventure
# 55789                                   lost-amber         Adventure
# 55790                                   lost-amber         Adventure
# 55791                                   falcon-age  Action-Adventure
#
#       ESRB_Rating Platform                   Publisher  \
# 0               E      Wii                    Nintendo
# 1             NaN      NES                    Nintendo
# 2               E      Wii                    Nintendo
# 3             NaN       PC            PUBG Corporation
# 4               E      Wii                    Nintendo
# 5               E       GB                    Nintendo
# 6               E       DS                    Nintendo
# 7               E       GB                    Nintendo
# 8               E      Wii                    Nintendo
# 9             NaN       PC                      Mojang
# 10            NaN      NES                    Nintendo
# 11              E      Wii                    Nintendo
# 12              E     X360      Microsoft Game Studios
# 13              E       DS                    Nintendo
# 14              E       DS                    Nintendo
# 15              E       GB                    Nintendo
# 16              E      Wii                    Nintendo
# 17              E      Wii                    Nintendo
# 18              E     SNES                    Nintendo
# 19              M      PS3              Rockstar Games
# 20              M      PS4              Rockstar Games
# 21              E       DS                    Nintendo
# 22            NaN       PC                     Unknown
# 23              E       GB                    Nintendo
# 24              E      3DS                    Nintendo
# 25              E       DS                    Nintendo
# 26              M      PS2              Rockstar Games
# 27              E      NES                    Nintendo
# 28              E      3DS                    Nintendo
# 29              E      GBA                    Nintendo
# ...           ...      ...                         ...
# 55762         NaN       PC                 NIS America
# 55763         NaN      GBA                       Atari
# 55764         NaN       NS                Idea Factory
# 55765         NaN       NS                     Unknown
# 55766         NaN     XOne                     Unknown
# 55767         NaN      PS4                     Unknown
# 55768         NaN       PC              Spike Chunsoft
# 55769         NaN       NS                     Unknown
# 55770         NaN      Int                      Coleco
# 55771         NaN      CDi   Philips Interactive Media
# 55772         NaN       NS                     Zerodiv
# 55773         NaN       NS                 Takara Tomy
# 55774           M     WiiU                     Unknown
# 55775         NaN       NS                Amazing Inc.
# 55776         NaN       NS  Forever Entertainment S.A.
# 55777           T       PC                      Konami
# 55778           E     XOne           Microsoft Studios
# 55779           E       PC                  THQ Nordic
# 55780         NaN     XOne                   505 Games
# 55781         NaN      PS4                   505 Games
# 55782         NaN       PC                   3D Realms
# 55783         NaN      PS4                   3D Realms
# 55784         NaN     XOne                   3D Realms
# 55785         NaN       NS                   3D Realms
# 55786         NaN       PC                Campo Santo
# 55787         NaN       PC                   505 Games
# 55788          RP       PC             Mooneye Studios
# 55789          RP      PS4             Mooneye Studios
# 55790          RP     XOne             Mooneye Studios
# 55791         NaN      PS4                     Unknown
#
#                           Developer  VGChartz_Score  Critic_Score  User_Score  \
# 0                      Nintendo EAD             NaN           7.7         NaN
# 1                      Nintendo EAD             NaN          10.0         NaN
# 2                      Nintendo EAD             NaN           8.2         9.1
# 3                  PUBG Corporation             NaN           NaN         NaN
# 4                      Nintendo EAD             NaN           8.0         8.8
# 5                        Game Freak             NaN           9.4         NaN
# 6                      Nintendo EAD             NaN           9.1         8.1
# 7             Bullet Proof Software             NaN           NaN         NaN
# 8                      Nintendo EAD             NaN           8.6         9.2
# 9                         Mojang AB             NaN          10.0         NaN
# 10                    Nintendo R&D1             NaN           NaN         NaN
# 11                     Nintendo EAD             NaN           5.9         4.5
# 12              Good Science Studio             NaN           6.7         NaN
# 13                     Nintendo EAD             NaN           8.4         NaN
# 14                     Nintendo EAD             NaN           9.1         9.4
# 15                       Game Freak             NaN           9.2         NaN
# 16                     Nintendo EAD             NaN           7.9         NaN
# 17                     Nintendo EAD             NaN           8.0         NaN
# 18                     Nintendo EAD             NaN           8.5         NaN
# 19                   Rockstar North             NaN           9.4         NaN
# 20                   Rockstar North             NaN           9.7         NaN
# 21                     Nintendo SDD             NaN           8.1         NaN
# 22                       Team Garry             NaN           NaN         NaN
# 23                    Nintendo R&D1             NaN           NaN         NaN
# 24     Nintendo EAD / Retro Studios             NaN           8.2         NaN
# 25                       Game Freak             NaN           8.6         NaN
# 26                   Rockstar North             NaN           9.5         NaN
# 27                    Nintendo R&D2             NaN           NaN         NaN
# 28                       Game Freak             NaN           8.9         9.7
# 29                       Game Freak             NaN           8.8         NaN
# ...                             ...             ...           ...         ...
# 55762                        Falcom             NaN           NaN         NaN
# 55763         Sensory Sweep Studios             NaN           NaN         NaN
# 55764                       Otomate             NaN           NaN         NaN
# 55765                 Baroque Decay             NaN           NaN         NaN
# 55766                 Baroque Decay             NaN           NaN         NaN
# 55767                 Baroque Decay             NaN           NaN         NaN
# 55768                      Lancarse             NaN           NaN         NaN
# 55769               Snowhydra Games             NaN           NaN         NaN
# 55770                        Coleco             NaN           NaN         NaN
# 55771           Viridis Corporation             NaN           NaN         NaN
# 55772                       ZeroDiv             NaN           NaN         NaN
# 55773                   Takara Tomy             NaN           NaN         NaN
# 55774                 Padaone Games             NaN           NaN         NaN
# 55775                  Amazing Inc.             NaN           NaN         NaN
# 55776    Forever Entertainment S.A.             NaN           NaN         NaN
# 55777                       Cygames             NaN           NaN         NaN
# 55778         Frontier Developments             NaN           NaN         NaN
# 55779         Frontier Developments             NaN           NaN         NaN
# 55780                Lab Zero Games             NaN           NaN         NaN
# 55781                Lab Zero Games             NaN           NaN         NaN
# 55782                    Voidpoint              NaN           NaN         NaN
# 55783                    Voidpoint              NaN           NaN         NaN
# 55784                    Voidpoint              NaN           NaN         NaN
# 55785                    Voidpoint              NaN           NaN         NaN
# 55786                  Campo Santo              NaN           NaN         NaN
# 55787                Lab Zero Games             NaN           NaN         NaN
# 55788               Mooneye Studios             NaN           NaN         NaN
# 55789               Mooneye Studios             NaN           NaN         NaN
# 55790               Mooneye Studios             NaN           NaN         NaN
# 55791               Outerloop Games             NaN           NaN         NaN
#
#        Total_Shipped  Global_Sales  NA_Sales  PAL_Sales  JP_Sales  \
# 0              82.86           NaN       NaN        NaN       NaN
# 1              40.24           NaN       NaN        NaN       NaN
# 2              37.14           NaN       NaN        NaN       NaN
# 3              36.60           NaN       NaN        NaN       NaN
# 4              33.09           NaN       NaN        NaN       NaN
# 5              31.38           NaN       NaN        NaN       NaN
# 6              30.80           NaN       NaN        NaN       NaN
# 7              30.26           NaN       NaN        NaN       NaN
# 8              30.22           NaN       NaN        NaN       NaN
# 9              30.01           NaN       NaN        NaN       NaN
# 10             28.31           NaN       NaN        NaN       NaN
# 11             28.02           NaN       NaN        NaN       NaN
# 12             24.00           NaN       NaN        NaN       NaN
# 13             23.96           NaN       NaN        NaN       NaN
# 14             23.60           NaN       NaN        NaN       NaN
# 15             23.10           NaN       NaN        NaN       NaN
# 16             22.67           NaN       NaN        NaN       NaN
# 17             21.13           NaN       NaN        NaN       NaN
# 18             20.61           NaN       NaN        NaN       NaN
# 19               NaN         20.32      6.37       9.85      0.99
# 20               NaN         19.39      6.06       9.71      0.60
# 21             19.01           NaN       NaN        NaN       NaN
# 22             18.58           NaN       NaN        NaN       NaN
# 23             18.14           NaN       NaN        NaN       NaN
# 24             18.11           NaN       NaN        NaN       NaN
# 25             17.67           NaN       NaN        NaN       NaN
# 26             17.30           NaN       NaN        NaN       NaN
# 27             17.28           NaN       NaN        NaN       NaN
# 28             16.37           NaN       NaN        NaN       NaN
# 29             16.22           NaN       NaN        NaN       NaN
# ...              ...           ...       ...        ...       ...
# 55762            NaN           NaN       NaN        NaN       NaN
# 55763            NaN           NaN       NaN        NaN       NaN
# 55764            NaN           NaN       NaN        NaN       NaN
# 55765            NaN           NaN       NaN        NaN       NaN
# 55766            NaN           NaN       NaN        NaN       NaN
# 55767            NaN           NaN       NaN        NaN       NaN
# 55768            NaN           NaN       NaN        NaN       NaN
# 55769            NaN           NaN       NaN        NaN       NaN
# 55770            NaN           NaN       NaN        NaN       NaN
# 55771            NaN           NaN       NaN        NaN       NaN
# 55772            NaN           NaN       NaN        NaN       NaN
# 55773            NaN           NaN       NaN        NaN       NaN
# 55774            NaN           NaN       NaN        NaN       NaN
# 55775            NaN           NaN       NaN        NaN       NaN
# 55776            NaN           NaN       NaN        NaN       NaN
# 55777            NaN           NaN       NaN        NaN       NaN
# 55778            NaN           NaN       NaN        NaN       NaN
# 55779            NaN           NaN       NaN        NaN       NaN
# 55780            NaN           NaN       NaN        NaN       NaN
# 55781            NaN           NaN       NaN        NaN       NaN
# 55782            NaN           NaN       NaN        NaN       NaN
# 55783            NaN           NaN       NaN        NaN       NaN
# 55784            NaN           NaN       NaN        NaN       NaN
# 55785            NaN           NaN       NaN        NaN       NaN
# 55786            NaN           NaN       NaN        NaN       NaN
# 55787            NaN           NaN       NaN        NaN       NaN
# 55788            NaN           NaN       NaN        NaN       NaN
# 55789            NaN           NaN       NaN        NaN       NaN
# 55790            NaN           NaN       NaN        NaN       NaN
# 55791            NaN           NaN       NaN        NaN       NaN
#
#        Other_Sales    Year  Last_Update  \
# 0              NaN  2006.0          NaN
# 1              NaN  1985.0          NaN
# 2              NaN  2008.0  11th Apr 18
# 3              NaN  2017.0  13th Nov 18
# 4              NaN  2009.0          NaN
# 5              NaN  1998.0          NaN
# 6              NaN  2006.0          NaN
# 7              NaN  1989.0          NaN
# 8              NaN  2009.0          NaN
# 9              NaN  2010.0  05th Aug 18
# 10             NaN  1985.0          NaN
# 11             NaN  2007.0          NaN
# 12             NaN  2010.0  29th Sep 18
# 13             NaN  2005.0          NaN
# 14             NaN  2005.0          NaN
# 15             NaN  2000.0          NaN
# 16             NaN  2008.0          NaN
# 17             NaN  2009.0          NaN
# 18             NaN  1991.0  10th Aug 18
# 19            3.12  2013.0          NaN
# 20            3.02  2014.0  03rd Jan 18
# 21             NaN  2006.0          NaN
# 22             NaN  2004.0          NaN
# 23             NaN  1989.0          NaN
# 24             NaN  2011.0          NaN
# 25             NaN  2007.0          NaN
# 26             NaN  2004.0          NaN
# 27             NaN  1990.0  09th Aug 18
# 28             NaN  2013.0  06th Jan 18
# 29             NaN  2003.0          NaN
# ...            ...     ...          ...
# 55762          NaN  2018.0  10th Jan 18
# 55763          NaN  2004.0  30th Dec 17
# 55764          NaN  2019.0  24th Feb 19
# 55765          NaN     NaN  17th Apr 18
# 55766          NaN     NaN  17th Apr 18
# 55767          NaN     NaN  17th Apr 18
df['Critic_Score'].fillna(0, inplace = True)

# %%
df['User_Score'].fillna(0, inplace=True)

# %%
df.drop_duplicates(subset ="Name", 
                     keep = 'first', inplace = True)

# %%
df['BG_Sam_Score'] = ''

# %%
df = df.drop(columns=['basename', 'VGChartz_Score', 'Total_Shipped', 'Global_Sales', 'NA_Sales', 'PAL_Sales', 'JP_Sales', 'Other_Sales', 'Last_Update', 'status', 'Vgchartzscore'])

# %%
for x in tqdm(range(len(df['Critic_Score']))):
    if df.loc[x, 'Critic_Score'] > 0:
        if df.loc[x, 'User_Score'] == 0:
            df.loc[x, 'BG_Sam_Score'] = df.loc[x, 'Critic_Score']
        elif df.loc[x, 'User_Score'] > 0:
            df.loc[x, 'BG_Sam_Score'] = (df.loc[x, 'Critic_Score']+df.loc[x, 'User_Score'])/2
    elif df.loc[x, 'Critic_Score'] == 0:
        if df.loc[x, 'User_Score'] == 0:
            df.loc[x, 'BG_Sam_Score'] = 0
        elif df.loc[x, 'User_Score'] > 0:
            df.loc[x, 'BG_Sam_Score'] = df.loc[x, 'User_Score']
# Out:
# HBox(children=(IntProgress(value=0, max=37102), HTML(value='')))
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 20
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-10-b3dfbb040d57> in <module>
#       1 for x in tqdm(range(len(df['Critic_Score']))):
# ----> 2     if df.loc[x, 'Critic_Score'] > 0:
#       3         if df.loc[x, 'User_Score'] == 0:
#       4             df.loc[x, 'BG_Sam_Score'] = df.loc[x, 'Critic_Score']
#       5         elif df.loc[x, 'User_Score'] > 0:
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1492             except (KeyError, IndexError, AttributeError):
#    1493                 pass
# -> 1494             return self._getitem_tuple(key)
#    1495         else:
#    1496             # we by definition only have the 0th axis
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#     866     def _getitem_tuple(self, tup):
#     867         try:
# --> 868             return self._getitem_lowerdim(tup)
#     869         except IndexingError:
#     870             pass
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _getitem_lowerdim(self, tup)
#     986         for i, key in enumerate(tup):
#     987             if is_label_like(key) or isinstance(key, tuple):
# --> 988                 section = self._getitem_axis(key, axis=i)
#     989
#     990                 # we have yielded a scalar ?
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1911         # fall thru to straight lookup
#    1912         self._validate_key(key, axis)
# -> 1913         return self._get_label(key, axis=axis)
#    1914
#    1915
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _get_label(self, label, axis)
#     139             raise IndexingError('no slices here, handle elsewhere')
#     140
# --> 141         return self.obj._xs(label, axis=axis)
#     142
#     143     def _get_loc(self, key, axis=None):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in xs(self, key, axis, level, drop_level)
#    3583                                                       drop_level=drop_level)
#    3584         else:
# -> 3585             loc = self.index.get_loc(key)
#    3586
#    3587             if isinstance(loc, np.ndarray):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
# -> 2659                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2660         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2661         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 20

# %%
df['BG_Sam_Score'].value_counts()

# %%
len(df)
# Out:
# 37102

# %% [markdown]
# The rank column is a rank of overall sales, so I'm going to drop all of the other sales columns. This ranking will be used as a measure of popularity and so, the rank will be the order in which we output the recommended games. I will drop the VGChartz_Score column since that column has no values and the Last_Update column since that is not important information. We can probably also drop the basename column since it is redundant information. I dropped status because I don't know what that means.

# %%
df = df.drop(columns=['basename', 'VGChartz_Score', 'Total_Shipped', 'Global_Sales', 'NA_Sales', 'PAL_Sales', 'JP_Sales', 'Other_Sales', 'Last_Update', 'status', 'Vgchartzscore'])

# %% [markdown]
# url and img_url could be used for output

# %% [markdown]
# All the duplicate rows

# %%
duplicateRows = df[df.duplicated(['Name'])]
print("Duplicate Rows based on a single column are:", duplicateRows, sep='\n')
# Out:
# Duplicate Rows based on a single column are:
#         Rank                                     Name             Genre  \
# 20        21                       Grand Theft Auto V            Action
# 32        33                       Grand Theft Auto V            Action
# 47        48               Call of Duty: Black Ops II           Shooter
# 51        52           Call of Duty: Modern Warfare 3           Shooter
# 56        57                                Minecraft              Misc
# 59        60                  Call of Duty: Black Ops           Shooter
# 83              M      PS3                              Activision
# 107             M     XOne                          Rockstar Games
# 134             M     XOne                              Activision
# 138             M      PS3                         Electronic Arts
# 152             M      PS3                              Activision
# 160             M     X360                          Rockstar Games
# 161             M      PS3                      Bethesda Softworks
# 166           E10      PS4             Sony Computer Entertainment
# 172             M     XOne                              Activision
# 175           E10      PS3     Sony Computer Entertainment America
# 188             M     XOne                          Rockstar Games
# 198           NaN      NES                                Nintendo
# 211           E10     XOne                       Microsoft Studios
# 212             M      PS3                              Activision
# 215             M      PS4  Warner Bros. Interactive Entertainment
# 220             M     X360                                 Ubisoft
# 222             M     X360                                 Ubisoft
# 229             M     XOne                              Activision
# 238             M     XOne                         Electronic Arts
# 242             E     X360                               EA Sports
# 250             M     XOne                      Bethesda Softworks
# ...           ...      ...                                     ...
# 55736           E      PS4                                  COWCAT
# 55737           E       NS                                  COWCAT
# 55738           E     XOne                                  COWCAT
# 55739           E       PC                                  COWCAT
# 55741         NaN       NS                                   Atooi
# 55743         NaN      PS4          Sony Interactive Entertainment
# 55744         NaN       PC                                 Unknown
# 55746         NaN      PS4                                    Sega
# 55747         NaN      PS4                                    Sega
# 55749         NaN       PC                                  Simogo
# 55750         NaN      OSX                                 Unknown
# 55753         NaN       NS                                 Unknown
# 55755           M      PS4                            Ysbryd Games
# 55759         E10       NS                      Team17 Digital Ltd
# 55761         NaN     XOne                                 Unknown
# 55762         NaN       PC                             NIS America
# 55766         NaN     XOne                                 Unknown
# 55767         NaN      PS4                                 Unknown
# 55768         NaN       PC                          Spike Chunsoft
# 55770         NaN      Int                                  Coleco
# 55777           T       PC                                  Konami
# 55779           E       PC                              THQ Nordic
# 55780         NaN     XOne                               505 Games
# 55781         NaN      PS4                               505 Games
# 55783         NaN      PS4                               3D Realms
# 55784         NaN     XOne                               3D Realms
# 55785         NaN       NS                               3D Realms
# 55787         NaN       PC                               505 Games
# 55789          RP      PS4                         Mooneye Studios
# 55790          RP     XOne                         Mooneye Studios
#
#                       Developer  Critic_Score  User_Score    Year  \
# 20               Rockstar North           9.7         NaN  2014.0
# 32               Rockstar North           NaN         NaN  2013.0
# 47                     Treyarch           NaN         NaN  2012.0
# 51                Infinity Ward           8.8         NaN  2011.0
# 56                       Mojang           NaN         NaN  2013.0
# 59                     Treyarch           8.7         NaN  2010.0
# 60               Rockstar North           NaN         NaN  2015.0
# 78                Infinity Ward           9.5         NaN  2009.0
# 79               Rockstar North          10.0         9.0  2008.0
# 83                Infinity Ward           7.5         NaN  2013.0
# 107              Rockstar North           9.0         9.0  2014.0
# 134                    Treyarch           NaN         NaN  2015.0
# 138                        Dice           8.5         NaN  2011.0
# 152               Infinity Ward           9.5         9.6  2007.0
# 160          Rockstar San Diego           9.5        10.0  2010.0
# 161       Bethesda Game Studios           9.0         NaN  2011.0
# 166                      Mojang           9.4         NaN  2014.0
# 172          Sledgehammer Games           NaN         NaN  2017.0
# 175                      Mojang           NaN         NaN  2014.0
# 188              Rockstar Games           NaN         NaN  2018.0
# 198                    Nintendo           NaN         NaN  1989.0
# 211                      Mojang           NaN         NaN  2014.0
# 212                    Treyarch           8.4         NaN  2008.0
# 215       CD Projekt Red Studio           NaN         NaN  2015.0
# 220            Ubisoft Montreal           NaN         NaN  2012.0
# 222            Ubisoft Montreal           9.1         NaN  2009.0
# 229          Sledgehammer Games           8.3         NaN  2014.0
# 238                     EA DICE           NaN         NaN  2016.0
# 242                   EA Canada           NaN         NaN  2012.0
# 250       Bethesda Game Studios           8.4         NaN  2015.0
# ...                         ...           ...         ...     ...
# 55736           Diabolical Mind           NaN         NaN  2018.0
# 55737           Diabolical Mind           NaN         NaN  2019.0
# 55738           Diabolical Mind           NaN         NaN  2018.0
# 55739           Diabolical Mind           NaN         NaN  2017.0
# 55741                     Atooi           NaN         NaN  2018.0
# 55743               DOMO Studio           NaN         NaN  2017.0
# 55744               DOMO Studio           NaN         NaN     NaN
# 55746                      Sega           NaN         NaN  2019.0
# 55747                      Sega           NaN         NaN  2019.0
# 55749                    Simogo           NaN         NaN  2014.0
# 55750                    Simogo           NaN         NaN     NaN
# 55753           Pendulo Studios           NaN         NaN     NaN
# 55755              Ackk Studios           NaN         NaN  2019.0
# 55759           Playtonic Games           NaN         NaN  2017.0
# 55761  Nihon Falcom Corporation           NaN         NaN     NaN
# 55762                    Falcom           NaN         NaN  2018.0
# 55766             Baroque Decay           NaN         NaN     NaN
# 55767             Baroque Decay           NaN         NaN     NaN
# 55768                  Lancarse           NaN         NaN  2019.0
# 55770                    Coleco           NaN         NaN  1983.0
# 55777                   Cygames           NaN         NaN  2018.0
# 55779     Frontier Developments           NaN         NaN  2018.0
# 55780            Lab Zero Games           NaN         NaN  2019.0
# 55781            Lab Zero Games           NaN         NaN  2019.0
# 55783                Voidpoint            NaN         NaN  2019.0
# 55784                Voidpoint            NaN         NaN  2019.0
# 55785                Voidpoint            NaN         NaN  2019.0
# 55787            Lab Zero Games           NaN         NaN  2019.0
# 55789           Mooneye Studios           NaN         NaN  2019.0
# 55790           Mooneye Studios           NaN         NaN  2019.0
#
#                                                      url  \
# 20     http://www.vgchartz.com/game/83196/grand-theft...
# 32     http://www.vgchartz.com/game/65883/grand-theft...
# 47     http://www.vgchartz.com/game/70715/call-of-dut...
# 51     http://www.vgchartz.com/game/44605/call-of-dut...
# 56     http://www.vgchartz.com/game/51765/minecraft/?...
# 59     http://www.vgchartz.com/game/44951/call-of-dut...
# 60     http://www.vgchartz.com/game/83197/grand-theft...
# 78     http://www.vgchartz.com/game/28847/call-of-dut...
# 79     http://www.vgchartz.com/game/7102/grand-theft-...
# 83     http://www.vgchartz.com/game/71507/call-of-dut...
# 107    http://www.vgchartz.com/game/73074/grand-theft...
# 134    http://www.vgchartz.com/game/85358/call-of-dut...
# 138    http://www.vgchartz.com/game/40230/battlefield...
# 152    http://www.vgchartz.com/game/7607/call-of-duty...
# 51     /games/boxart/full_call-of-duty-modern-warfare...
# 56         /games/boxart/full_7845034AmericaFrontccc.jpg
# 59     /games/boxart/full_call-of-duty-black-ops_3Ame...
# 60         /games/boxart/full_9031276AmericaFrontccc.jpg
# 78     /games/boxart/full_call-of-duty-modern-warfare...
# 79         /games/boxart/full_1729769AmericaFrontccc.jpg
# 83         /games/boxart/full_3698558AmericaFrontccc.jpg
# 107        /games/boxart/full_8047513AmericaFrontccc.jpg
# 134        /games/boxart/full_8414457AmericaFrontccc.jpg
# 138    /games/boxart/full_battlefield-3_278AmericaFro...
# 152          /games/boxart/full_75346AmericaFrontccc.jpg
# 160        /games/boxart/full_2634795AmericaFrontccc.jpg
# 161    /games/boxart/full_the-elder-scrolls-v-skyrim_...
# 166        /games/boxart/full_6776646AmericaFrontccc.jpg
# 172        /games/boxart/full_9289123AmericaFrontccc.jpg
# 175        /games/boxart/full_6168598AmericaFrontccc.jpg
# 188        /games/boxart/full_1425733AmericaFrontccc.jpg
# 198        /games/boxart/full_4580639AmericaFrontccc.jpg
# 211         /games/boxart/full_739755AmericaFrontccc.jpg
# 212        /games/boxart/full_4070815AmericaFrontccc.jpg
# 215        /games/boxart/full_7461389AmericaFrontccc.jpg
# 220        /games/boxart/full_7723506AmericaFrontccc.jpg
# 222        /games/boxart/full_8353337AmericaFrontccc.jpg
# 229        /games/boxart/full_6401955AmericaFrontccc.jpg
# 238         /games/boxart/full_601699AmericaFrontccc.png
# 242        /games/boxart/full_6831972AmericaFrontccc.jpg
# 250        /games/boxart/full_4876777AmericaFrontccc.jpg
# ...                                                  ...
# 55736      /games/boxart/full_9682471AmericaFrontccc.jpg
# 55737      /games/boxart/full_6911427AmericaFrontccc.png
# 55738      /games/boxart/full_4448604AmericaFrontccc.jpg
# 55739      /games/boxart/full_2663151AmericaFrontccc.jpg
# 55741      /games/boxart/full_4190650AmericaFrontccc.png
# 55743        /games/boxart/full_2750888JapanFrontccc.jpg
# 55744                          /games/boxart/default.jpg
# 55746        /games/boxart/full_4078189JapanFrontccc.jpg
# 55747      /games/boxart/full_6278319AmericaFrontccc.jpg
# 55749                          /games/boxart/default.jpg
# 55750                          /games/boxart/default.jpg
# 55753          /games/boxart/full_7165347PALFrontccc.jpg
# 55755      /games/boxart/full_9067390AmericaFrontccc.jpg
# 55759      /games/boxart/full_3225203AmericaFrontccc.png
# 55761                          /games/boxart/default.jpg
# 55762                          /games/boxart/default.jpg
# 55766                          /games/boxart/default.jpg
# 55767                          /games/boxart/default.jpg
# 55768      /games/boxart/full_6526231AmericaFrontccc.jpg
# 55770       /games/boxart/full_329720AmericaFrontccc.jpg
# 55777      /games/boxart/full_3463465AmericaFrontccc.jpg
# 55779      /games/boxart/full_9077703AmericaFrontccc.jpg
# 55780      /games/boxart/full_2926149AmericaFrontccc.jpg
# 55781      /games/boxart/full_2381591AmericaFrontccc.jpg
# 55783      /games/boxart/full_5465076AmericaFrontccc.jpg
# 55784      /games/boxart/full_7644791AmericaFrontccc.jpg
# 55785      /games/boxart/full_3418565AmericaFrontccc.jpg
# 55787      /games/boxart/full_6339426AmericaFrontccc.jpg
# 55789      /games/boxart/full_6514293AmericaFrontccc.jpg
# 55790      /games/boxart/full_6799693AmericaFrontccc.jpg
#
# [18690 rows x 12 columns]

# %% [markdown]
# Getting rid of the duplicate rows and keeping the first.

# %%
df.drop_duplicates(subset ="Name", 
                     keep = 'first', inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 37102 entries, 0 to 55791
# Data columns (total 12 columns):
# Rank            37102 non-null int64
# Name            37102 non-null object
# Genre           37102 non-null object
# ESRB_Rating     13523 non-null object
# Platform        37102 non-null object
# Publisher       37102 non-null object
# Developer       37087 non-null object
# Critic_Score    3946 non-null float64
# User_Score      264 non-null float64
# Year            36561 non-null float64
# url             37102 non-null object
# img_url         37102 non-null object
# dtypes: float64(3), int64(1), object(8)
# memory usage: 3.7+ MB

# %% [markdown]
# For the rest of the missing data I am just going to fill the missing ESRB rating with the mode. The missing developer I will fill with the mode as well. I'm just going to drop the critic and user score since they are missing over 85%. The missing year I will fill with the mode.

# %%
df['ESRB_Rating'] = df['ESRB_Rating'].fillna(df['ESRB_Rating'].mode()[0])

# %%
df['Developer'] = df['Developer'].fillna(df['Developer'].mode()[0])

# %%
df = df.drop(columns=['Critic_Score', 'User_Score'])

# %%
df['Year'] = df['Year'].fillna(df['Year'].mode()[0])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 37102 entries, 0 to 55791
# Data columns (total 10 columns):
# Rank           37102 non-null int64
# Name           37102 non-null object
# Genre          37102 non-null object
# ESRB_Rating    37102 non-null object
# Platform       37102 non-null object
# Publisher      37102 non-null object
# Developer      37102 non-null object
# Year           37102 non-null float64
# url            37102 non-null object
# img_url        37102 non-null object
# dtypes: float64(1), int64(1), object(8)
# memory usage: 3.1+ MB

# %%
#plt.hist(df['Genre'])

# %%
df.head()
# Out:
#    Rank                           Name     Genre ESRB_Rating Platform  \
# 0     1                     Wii Sports    Sports           E      Wii
# 1     2              Super Mario Bros.  Platform           E      NES
# 2     3                 Mario Kart Wii    Racing           E      Wii
# 3     4  PlayerUnknown's Battlegrounds   Shooter           E       PC
# 4     5              Wii Sports Resort    Sports           E      Wii
#
#           Publisher         Developer    Year  \
# 0          Nintendo      Nintendo EAD  2006.0
# 1          Nintendo      Nintendo EAD  1985.0
# 2          Nintendo      Nintendo EAD  2008.0
# 3  PUBG Corporation  PUBG Corporation  2017.0
# 4          Nintendo      Nintendo EAD  2009.0
#
#                                                  url  \
# 0  http://www.vgchartz.com/game/2667/wii-sports/?...
# 1  http://www.vgchartz.com/game/6455/super-mario-...
# 2  http://www.vgchartz.com/game/6968/mario-kart-w...
# 3  http://www.vgchartz.com/game/215988/playerunkn...
# 4  http://www.vgchartz.com/game/24656/wii-sports-...
#
#                                          img_url
# 0  /games/boxart/full_2258645AmericaFrontccc.jpg
# 1                   /games/boxart/8972270ccc.jpg
# 2  /games/boxart/full_8932480AmericaFrontccc.jpg
# 3  /games/boxart/full_8052843AmericaFrontccc.jpg
# 4  /games/boxart/full_7295041AmericaFrontccc.jpg
