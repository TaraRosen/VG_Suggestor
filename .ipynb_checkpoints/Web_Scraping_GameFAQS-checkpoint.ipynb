# %%
from bs4 import BeautifulSoup
import requests
import re
import pandas as pd

# %%
import requests
from bs4 import BeautifulSoup

response = requests.get('https://www.gamefaqs.com', headers={'User-Agent': 'Mozilla/5.0'})

# %%
response.status_code
# Out:
# 200

# %%
soup = BeautifulSoup(response.content, 'html.parser')

# %%
soup.title
# Out:
# <title>GameFAQs - Video Game Cheats, Reviews, FAQs, Message Boards, and More</title>

# %%
soup.get_text(strip = True) #gets rid of new lines
# Out:
# 'GameFAQs - Video Game Cheats, Reviews, FAQs, Message Boards, and Morewindow._taboola=window._taboola || []; _taboola.push({home:\'auto\'}); function setUpAgknTag(tag){tag.setBpId("cbsinteractive");}var _gaq = _gaq || [];  _gaq.push([\'nT._setAccount\', \'UA-27653683-1\']);  _gaq.push([\'nT._setAllowLinker\', true]); _gaq.push([\'nT._setSampleRate\', \'1\']); _gaq.push([\'nT._trackPageview\']); _gaq.push([\'_setAccount\', \'UA-22577913-2\']); _gaq.push([\'_setSampleRate\', \'5\']); _gaq.push([\'_setCustomVar\',1,\'PageType\',\'2000\',3]); _gaq.push([\'_setCustomVar\',2,\'LoggedIn\',\'No\',2]); _gaq.push([\'_setCustomVar\',3,\'UserLevel\',\'0\',3]);  _gaq.push([\'_trackPageview\']);(function(id){\r\n\t    function append(scriptid,url,async){var d=document,sn=\'script\',f=d.getElementsByTagName(sn)[0];if(!f)f=d.head;var s=d.createElement(sn);s.async=!0;s.id=scriptid;s.src=url;f.parentNode.insertBefore(s,f)}\r\n\t  window.evidon={}; window.evidon.id=id; append(\'evidon-notice\',\'//game
# ...

# %%
soup.find_all(string = 'Switch')  #capitalized
# Out:
# ['Switch', 'Switch']

# %%
type(soup.find_all(string = 'Switch'))  #element-tag
# Out:
# bs4.element.ResultSet

# %%
len(soup.find_all(string = 'Switch'))  #how many results
# Out:
# 2

# %%
soup.find_all(string = 'Switch')[0].find_parents()
# Out:
# [<a href="/switch">Switch</a>,
#  <li><a href="/switch">Switch</a></li>,
#  <ul class="sidenav_submenu"><li><a href="/3ds">3DS</a></li><li><a href="/android">Android</a></li><li><a href="/iphone">iOS</a></li><li><a href="/pc">PC</a></li><li><a href="/ps3">PlayStation 3</a></li><li><a href="/ps4">PlayStation 4</a></li><li><a href="/switch">Switch</a></li><li><a href="/vita">Vita</a></li><li><a href="/xbox360">Xbox 360</a></li><li><a href="/xboxone">Xbox One</a></li></ul>,
# ...

# %%
len(soup.find_all(string = 'Switch')[0].find_parents())
# Out:
# 10

# %%
soup.find_all('p',string = 'Switch')  #no results
# Out:
# []

# %%
soup.find_all('a',string = 'Switch')
# Out:
# [<a href="/switch">Switch</a>, <a href="/switch">Switch</a>]

# %%
soup.find_all('a',string = 'Switch')[0].get('href')
# Out:
# '/switch'

# %%
response = requests.get('https://gamefaqs.gamespot.com/switch/category/999-all?region=1', headers ={'User-Agent': 'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/59.0.3071.115 Safari/537.36'})

# %%
response.status_code
# Out:
# 200

# %%
soup = BeautifulSoup(response.content, 'html.parser')

# %%
soup.get_text(strip = True)
# Out:
# 'Nintendo Switch Cheats, Reviews, FAQs, Message Boards, and More - GameFAQswindow._taboola=window._taboola || []; _taboola.push({other:\'auto\'}); function setUpAgknTag(tag){tag.setBpId("cbsinteractive");}var _gaq = _gaq || [];  _gaq.push([\'nT._setAccount\', \'UA-27653683-1\']);  _gaq.push([\'nT._setAllowLinker\', true]); _gaq.push([\'nT._setSampleRate\', \'1\']); _gaq.push([\'nT._trackPageview\']); _gaq.push([\'_setAccount\', \'UA-22577913-2\']); _gaq.push([\'_setSampleRate\', \'5\']); _gaq.push([\'_setCustomVar\',1,\'PageType\',\'6067\',3]); _gaq.push([\'_setCustomVar\',2,\'LoggedIn\',\'No\',2]); _gaq.push([\'_setCustomVar\',3,\'UserLevel\',\'0\',3]);  _gaq.push([\'_trackPageview\']);(function(id){\r\n\t    function append(scriptid,url,async){var d=document,sn=\'script\',f=d.getElementsByTagName(sn)[0];if(!f)f=d.head;var s=d.createElement(sn);s.async=!0;s.id=scriptid;s.src=url;f.parentNode.insertBefore(s,f)}\r\n\t  window.evidon={}; window.evidon.id=id; append(\'evidon-notice\',\'
# ...
