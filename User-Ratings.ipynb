# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
pd.set_option('display.max_columns', None)
# %%capture
from tqdm import tqdm_notebook as tqdm
tqdm().pandas()
# Out:
# UsageError: Line magic function `%%capture` not found.

# %%
df = pd.read_csv('ratings_Video_Games.csv')

# %%
df.head()
# Out:
#     AB9S9279OZ3QO  0078764343  5.0  1373155200
# 0  A24SSUT5CSW8BH  0078764343  5.0  1377302400
# 1   AK3V0HEBJMQ7J  0078764343  4.0  1372896000
# 2  A10BECPH7W8HM7  043933702X  5.0  1404950400
# 3  A2PRV9OULX1TWP  043933702X  5.0  1386115200
# 4   AE7GUHCDQQ4UI  043933702X  1.0  1366156800

# %%
df
# Out:
#           AB9S9279OZ3QO  0078764343  5.0  1373155200
# 0        A24SSUT5CSW8BH  0078764343  5.0  1377302400
# 1         AK3V0HEBJMQ7J  0078764343  4.0  1372896000
# 2        A10BECPH7W8HM7  043933702X  5.0  1404950400
# 3        A2PRV9OULX1TWP  043933702X  5.0  1386115200
# 4         AE7GUHCDQQ4UI  043933702X  1.0  1366156800
# 5         A48ABFDDRMKI8  043933702X  5.0  1374192000
# 6        A26B0P6K95SIKW  0439339960  3.0  1288569600
# 7         AZ3UWOC8QSO6C  0439339987  5.0  1366848000
# 8        A182S3ANC0W7DL  0439342260  4.0  1355875200
# 9         AY5Q951JAZAX9  0439374391  5.0  1356393600
# 10       A1TL721YECDIM8  0439394422  3.0  1389657600
# 11        APDCEJMFDO2YT  0439394422  5.0  1285545600
# 12        AFJ7A9CSEPZNY  043940133X  4.0  1168300800
# 13       A14YVGE643TRJK  043940133X  1.0  1324944000
# 14       A2H3TQWU51W1WE  043940133X  5.0  1299456000
# 15       A3KO10N2ODLHBR  043940133X  5.0  1258329600
# 16       A1T98OCCYW6OBI  043940133X  2.0  1343779200
# ...
